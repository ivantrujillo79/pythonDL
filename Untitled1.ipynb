# %% [markdown]
# <a href="https://colab.research.google.com/github/ivantrujillo79/pythonDL/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

DATADIR = "./drive/My Drive/CALIDAD FACING/"
CATEGORIES = ["Coca-cola 2 litros", "Leche semidescremada soprole 1 litro", "Te supremo celan premium 100 bolsas", "biosal 50%menos sodio 850g", "cachantun origen natural 1600ml"]

for category in CATEGORIES:
  path = os.path.join(DATADIR, category)
  for img in os.listdir(path):
      img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
      plt.imshow(img_array, cmap="gray")
      plt.show()
      break
  break

print(img_array)
print(img_array.shape)

IMGSIZE = 500
new_array = cv2.resize(img_array, (IMGSIZE, IMGSIZE))
plt.imshow(new_array, cmap = 'Blues')
plt.show()

plt.imshow(new_array, cmap = 'Greens')
plt.show()

plt.imshow(new_array, cmap = 'Reds')
plt.show()

print(new_array.shape)
# Out:
# [[165 167 167 ... 160 158 154]
#  [165 165 165 ... 159 157 154]
#  [169 167 165 ... 159 158 158]
#  ...
#  [117 118 115 ...  99  97  97]
#  [119 119 117 ... 100  98  98]
#  [118 116 115 ... 100  97  98]]
# (4128, 3096)
# (500, 500)

# %%
training_data = []
def create_training_data():
    for category in CATEGORIES:
      path = os.path.join(DATADIR, category)
      class_num = CATEGORIES.index(category)
      for img in os.listdir(path):
        try:
          img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
          new_array = cv2.resize(img_array, (IMGSIZE, IMGSIZE))
          training_data.append([new_array, class_num])
        except Exception as e:
          pass

create_training_data()

# %%
print(len(training_data))
# Out:
# 794

# %%
import random
random.shuffle(training_data)

# %%
for sample in training_data[:10]:
  print(sample[1])
# Out:
# 4
# 4
# 1
# 4
# 4
# 1
# 4
# 4
# 4
# 4

# %%
X = []
y = []

# %%
for features, label in training_data:
  X.append(features)
  y.append(label)

X = np.array(X).reshape(-1, IMGSIZE, IMGSIZE, 1)

# %%
import pickle
pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

X[1]

# %%
print(len(X))
X[700]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle

X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))

X = X/255.0

model = Sequential()
model.add(Conv2D(64, (3,3), input_shape = X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss="binary_crossentropy",
              optimizer="adam",
              metrics=['accuracy'])

model.fit(X, y, batch_size=32, epochs = 10, validation_split=0.1)
# Out:
# Train on 714 samples, validate on 80 samples
# Epoch 1/10
# 714/714 [==============================] - 408s 571ms/sample - loss: -133422.1917 - acc: 0.3235 - val_loss: -735215.3000 - val_acc: 0.2750
# Epoch 2/10
# 714/714 [==============================] - 403s 564ms/sample - loss: -3943129.4314 - acc: 0.3235 - val_loss: -12188879.2000 - val_acc: 0.2750
# Epoch 3/10
# 714/714 [==============================] - 418s 586ms/sample - loss: -32248375.1261 - acc: 0.3235 - val_loss: -75247686.4000 - val_acc: 0.2750
# Epoch 4/10
# 714/714 [==============================] - 406s 568ms/sample - loss: -150270790.5882 - acc: 0.3235 - val_loss: -287678528.0000 - val_acc: 0.2750
# Epoch 5/10
# 714/714 [==============================] - 398s 558ms/sample - loss: -476692350.9244 - acc: 0.3235 - val_loss: -821371404.8000 - val_acc: 0.2750
# Epoch 6/10
# 714/714 [==============================] - 393s 550ms/sample - loss: -1224230071.7535 - acc: 0.3235 - val_loss: -1921256985.6000 - val_acc: 0.2750
# Epoch 7/10
# 714/714 [==============================] - 393s 550ms/sample - loss: -2637044308.6162 - acc: 0.3235 - val_loss: -3927046963.2000 - val_acc: 0.2750
# Epoch 8/10
# 714/714 [==============================] - 397s 555ms/sample - loss: -5142849198.9692 - acc: 0.3235 - val_loss: -7303931699.2000 - val_acc: 0.2750
# Epoch 9/10
# 714/714 [==============================] - 395s 554ms/sample - loss: -9116359688.6050 - acc: 0.3235 - val_loss: -12551397376.0000 - val_acc: 0.2750
# Epoch 10/10
# 714/714 [==============================] - 395s 553ms/sample - loss: -15218661218.2409 - acc: 0.3235 - val_loss: -20246786867.2000 - val_acc: 0.2750

# %%
model.save('64x3-CNN.model')

# %%
import cv2
import tensorflow as tf

CATEGORIAS = ["Coca-cola 2 litros", "Leche semidescremada soprole 1 litro", "Te supremo celan premium 100 bolsas", "biosal 50%menos sodio 850g", "cachantun origen natural 1600ml"]

def prepare(filepath):
  IMG_SIZE = 500
  img_arreglo = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
  nuevo_array = cv2.resize(img_arreglo, (IMG_SIZE, IMG_SIZE))
  return nuevo_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)


model = tf.keras.models.load_model("64x3-CNN.model")

prediction = model.predict([prepare('./20200225_212645.jpg')])
print( CATEGORIAS[int(prediction[0][0])])
# Out:
# Leche semidescremada soprole 1 litro
